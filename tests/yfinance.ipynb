# %%
import yfinance as yf

# %%
stock = yf.Ticker("VALE3.SA")
stock
# Out:
# yfinance.Ticker object <VALE3.SA>

# %% [markdown]
# # Stock Actions

# %%
stock.actions
# Out:
#                            Dividends  Stock Splits
# Date
# 2004-08-19 00:00:00-03:00   0.000000           3.0
# 2006-05-22 00:00:00-03:00   0.000000           2.0
# 2007-09-03 00:00:00-03:00   0.000000           2.0
# 2008-04-11 00:00:00-03:00   0.436585           0.0
# 2008-10-17 00:00:00-03:00   0.138520           0.0
# 2009-04-16 00:00:00-03:00   0.524586           0.0
# 2009-10-16 00:00:00-03:00   0.492036           0.0
# 2010-04-15 00:00:00-03:00   0.421661           0.0
# 2010-10-15 00:00:00-03:00   0.471881           0.0
# 2011-01-17 00:00:00-02:00   0.320048           0.0
# 2011-04-14 00:00:00-03:00   0.608247           0.0
# 2011-08-12 00:00:00-03:00   0.933403           0.0
# 2011-10-17 00:00:00-02:00   0.634329           0.0
# 2012-04-16 00:00:00-03:00   1.075280           0.0
# 2012-10-17 00:00:00-03:00   1.186520           0.0
# 2013-04-17 00:00:00-03:00   0.864045           0.0
# 2013-10-18 00:00:00-03:00   0.120605           0.0
# ...

# %%
stock.dividends
# Out:
# Date
# 2008-04-11 00:00:00-03:00    0.436585
# 2008-10-17 00:00:00-03:00    0.138520
# 2009-04-16 00:00:00-03:00    0.524586
# 2009-10-16 00:00:00-03:00    0.492036
# 2010-04-15 00:00:00-03:00    0.421661
# 2010-10-15 00:00:00-03:00    0.471881
# 2011-01-17 00:00:00-02:00    0.320048
# 2011-04-14 00:00:00-03:00    0.608247
# 2011-08-12 00:00:00-03:00    0.933403
# 2011-10-17 00:00:00-02:00    0.634329
# 2012-04-16 00:00:00-03:00    1.075280
# 2012-10-17 00:00:00-03:00    1.186520
# 2013-04-17 00:00:00-03:00    0.864045
# 2013-10-18 00:00:00-03:00    0.120605
# 2014-04-15 00:00:00-03:00    0.898904
# 2014-10-17 00:00:00-03:00    0.990870
# 2015-04-15 00:00:00-03:00    0.601761
# 2015-10-16 00:00:00-03:00    0.373610
# 2016-12-02 00:00:00-02:00    0.166294
# 2017-04-24 00:00:00-03:00    0.905572
# 2017-12-22 00:00:00-02:00    0.419912
# 2018-03-07 00:00:00-03:00    0.488511
# 2018-08-03 00:00:00-03:00    1.480362
# 2019-12-27 00:00:00-03:00    1.414364
# ...

# %%
stock.splits
# Out:
# Date
# 2004-08-19 00:00:00-03:00    3.0
# 2006-05-22 00:00:00-03:00    2.0
# 2007-09-03 00:00:00-03:00    2.0
# Name: Stock Splits, dtype: float64

# %%
stock.capital_gains
# Out:
# []

# %% [markdown]
# # Share count

# %%
stock.get_shares_full()
# Out:
# 2022-12-08 00:00:00-03:00    4664059904
# 2022-12-30 00:00:00-03:00    4717590016
# 2023-01-01 00:00:00-03:00    4664059904
# 2023-01-04 00:00:00-03:00    4674520064
# 2023-01-06 00:00:00-03:00    4672779776
#                                 ...
# 2024-05-25 00:00:00-03:00    4280329984
# 2024-05-29 00:00:00-03:00    4374790144
# 2024-05-29 00:00:00-03:00    4275689984
# 2024-06-05 00:00:00-03:00    4319680000
# 2024-06-05 00:00:00-03:00    4275689984
# Length: 147, dtype: int64

# %% [markdown]
# # Dados financeiros

# %% [markdown]
# ## Demonstração de resultados

# %%
stock.income_stmt
# Out:
#                                                        2023-12-31  \
# Tax Effect Of Unusual Items                          -568659000.0
# Tax Rate For Calcs                                          0.273
# Normalized EBITDA                                   17643000000.0
# Total Unusual Items                                 -2083000000.0
# Total Unusual Items Excluding Goodwill              -2083000000.0
# Net Income From Continuing Operation Net Minori...   7983000000.0
# Reconciled Depreciation                              3070000000.0
# Reconciled Cost Of Revenue                          21066000000.0
# EBITDA                                              15560000000.0
# EBIT                                                12490000000.0
# Net Interest Income                                 -1515000000.0
# Interest Expense                                     1339000000.0
# Interest Income                                               NaN
# ...

# %%
stock.quarterly_income_stmt
# Out:
#                                                            2024-03-31  \
# Tax Effect Of Unusual Items                          -94006557.377049
# Tax Rate For Calcs                                           0.209836
# Normalized EBITDA                                        3551000000.0
# Total Unusual Items                                      -448000000.0
# Total Unusual Items Excluding Goodwill                   -448000000.0
# Net Income From Continuing Operation Net Minori...       1679000000.0
# Reconciled Depreciation                                   714000000.0
# Reconciled Cost Of Revenue                               4663000000.0
# EBITDA                                                   3103000000.0
# EBIT                                                     2389000000.0
# Net Interest Income                                      -147000000.0
# Interest Expense                                          254000000.0
# ...

# %% [markdown]
# ## Balanço Patrimonial

# %%
stock.balance_sheet
# Out:
#                                                      2023-12-31  \
# Treasury Shares Number                              239153280.0
# Ordinary Shares Number                             4299854288.0
# Share Issued                                       4539007568.0
# Net Debt                                          11736000000.0
# Total Debt                                        16797000000.0
# ...                                                         ...
# Allowance For Doubtful Accounts Receivable          -44000000.0
# Gross Accounts Receivable                          4241000000.0
# Cash Cash Equivalents And Short Term Investments   3660000000.0
# Other Short Term Investments                         51000000.0
# Cash And Cash Equivalents                          3609000000.0
#
#                                                      2022-12-31  \
# Treasury Shares Number                              295810551.0
# Ordinary Shares Number                             4483078700.0
# ...

# %%
stock.quarterly_balance_sheet
# Out:
#                                                      2024-03-31  \
# Treasury Shares Number                              258676398.0
# Ordinary Shares Number                             4280331182.0
# Share Issued                                       4539007580.0
# Net Debt                                          12079000000.0
# Total Debt                                        17295000000.0
# ...                                                         ...
# Allowance For Doubtful Accounts Receivable          -44000000.0
# Gross Accounts Receivable                          2277000000.0
# Cash Cash Equivalents And Short Term Investments   3834000000.0
# Other Short Term Investments                         44000000.0
# Cash And Cash Equivalents                          3790000000.0
#
#                                                      2023-12-31  \
# Treasury Shares Number                              239153280.0
# Ordinary Shares Number                             4299854288.0
# ...

# %% [markdown]
# ## Fluxo de caixa

# %%
stock.cash_flow
# Out:
#                                                    2023-12-31     2022-12-31  \
# Free Cash Flow                                   7245000000.0   6039000000.0
# Repurchase Of Capital Stock                     -2714000000.0  -6036000000.0
# Repayment Of Debt                                -891000000.0  -2524000000.0
# Issuance Of Debt                                 1950000000.0   1275000000.0
# Capital Expenditure                             -5920000000.0  -5446000000.0
# End Cash Position                                3609000000.0   4736000000.0
# Other Cash Adjustment Outside Changein Cash      -703000000.0    -11000000.0
# Beginning Cash Position                          4736000000.0  11721000000.0
# Effect Of Exchange Rate Changes                    69000000.0    138000000.0
# Changes In Cash                                  -493000000.0  -7112000000.0
# Cash Flow From Discontinued Operation                     NaN            NaN
# ...

# %%
stock.quarterly_cash_flow
# Out:
#                                                   2024-03-31    2023-12-31  \
# Free Cash Flow                                  2181000000.0  2671000000.0
# Repurchase Of Capital Stock                     -275000000.0   -44000000.0
# Repayment Of Debt                               -103000000.0  -119000000.0
# Issuance Of Debt                                 870000000.0           0.0
# Capital Expenditure                            -1395000000.0 -2118000000.0
# End Cash Position                               3790000000.0  3609000000.0
# Other Cash Adjustment Outside Changein Cash              NaN  -703000000.0
# Beginning Cash Position                         3609000000.0  3967000000.0
# Effect Of Exchange Rate Changes                  -40000000.0    19000000.0
# Changes In Cash                                  221000000.0   326000000.0
# Financing Cash Flow                            -1836000000.0 -2236000000.0
# ...

# %% [markdown]
# # Investidores

# %%
stock.major_holders
# Out:
# /home/gabriel/Projects/3A-ai/.venv/lib/python3.11/site-packages/yfinance/scrapers/holders.py:39: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   def institutional(self) -> pd.DataFrame:
#   Breakdown                             Unnamed: 1
# 0    11.47%        % of Shares Held by All Insider
# 1    44.09%       % of Shares Held by Institutions
# 2    49.80%        % of Float Held by Institutions
# 3       554  Number of Institutions Holding Shares

# %%
stock.institutional_holders
# Out:
# /home/gabriel/Projects/3A-ai/.venv/lib/python3.11/site-packages/yfinance/scrapers/holders.py:39: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   def institutional(self) -> pd.DataFrame:

# %%
stock.mutualfund_holders
# Out:
# /home/gabriel/Projects/3A-ai/.venv/lib/python3.11/site-packages/yfinance/scrapers/holders.py:39: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   def institutional(self) -> pd.DataFrame:

# %% [markdown]
# # Ganho por ação (EPS)
#
# Mostra datas de ganhos futuros e históricos, retornos no máximo nos próximos 4 trimestres e nos últimos 8 trimestres por padrão.

# %%
stock.earnings_dates
# Out:
# /home/gabriel/Projects/3A-ai/.venv/lib/python3.11/site-packages/yfinance/base.py:2093: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#                            EPS Estimate  Reported EPS  Surprise(%)
# Earnings Date
# 2025-04-25 11:00:00-03:00           NaN           NaN          NaN
# 2025-04-22 16:00:00-03:00           NaN           NaN          NaN
# 2025-02-20 16:00:00-03:00           NaN           NaN          NaN
# 2024-10-24 16:00:00-03:00           NaN           NaN          NaN
# 2024-07-25 16:00:00-03:00          3.25           NaN          NaN
# 2024-04-26 11:00:00-03:00          2.43          2.02      -0.1687
# 2024-04-26 11:00:00-03:00          2.43          2.02      -0.1687
# 2024-04-24 21:00:00-03:00          0.47          0.39      -0.1702
# 2024-03-08 07:00:00-03:00          4.64          2.84      -0.3879
# ...

# %% [markdown]
# # Notícias

# %%
stock.news
# Out:
# [{'uuid': '9fb209b3-5e62-3141-a252-91dc85ccd9c2',
#   'title': "Investors Overreacted to Expedia's Earnings",
#   'publisher': 'GuruFocus.com',
#   'link': 'https://finance.yahoo.com/news/investors-overreacted-expedias-earnings-140003675.html',
#   'providerPublishTime': 1717682403,
#   'type': 'STORY',
#   'thumbnail': {'resolutions': [{'url': 'https://s.yimg.com/uu/api/res/1.2/PHbHU2LTRsHJ8k.NoPuL5g--~B/aD0yNzI7dz04NjY7YXBwaWQ9eXRhY2h5b24-/https://media.zenfs.com/en/us.finance.gurufocus/cd8de9fe6d7cf8404b7121e6e8fe78eb',
#      'width': 866,
#      'height': 272,
#      'tag': 'original'},
#     {'url': 'https://s.yimg.com/uu/api/res/1.2/2mxuPLJu1nn3pA_ec.bswQ--~B/Zmk9ZmlsbDtoPTE0MDtweW9mZj0wO3c9MTQwO2FwcGlkPXl0YWNoeW9u/https://media.zenfs.com/en/us.finance.gurufocus/cd8de9fe6d7cf8404b7121e6e8fe78eb',
#      'width': 140,
#      'height': 140,
#      'tag': '140x140'}]},
#   'relatedTickers': ['EXPE', 'GOOG']},
#  {'uuid': 'c4acd21e-5418-3ab4-bd8a-86dfcef945ee',
# ...

# %% [markdown]
# # Representação
